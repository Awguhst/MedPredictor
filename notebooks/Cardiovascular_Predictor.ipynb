# %%
# Data manipulation and analysis
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, precision_score, recall_score, confusion_matrix, classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Hyperparameter optimization
import optuna

# Utility
import pickle
import warnings

# %%
# Set up random seed
random_seed=42

# Load the dataset 
df = pd.read_csv("../data/Cardiovascular_Data.csv")
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
# Prepare the feature
X = df.drop(["cardio"], axis=1)  
y = df['cardio']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %%
model = xgb.XGBClassifier().fit(X_train, y_train)

# Make predictions and evaluate
y_test_pred = model.predict(X_test)

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74      6988
#            1       0.75      0.70      0.73      7012
#
#     accuracy                           0.74     14000
#    macro avg       0.74      0.74      0.74     14000
# weighted avg       0.74      0.74      0.74     14000

# %%
# Define the objective function for Optuna
def objective(trial):
    # Hyperparameter search space
    param = {
        'predictor': 'gpu_predictor',  
        'objective': 'binary:logistic', 
        'eval_metric': 'logloss',  
        'verbosity': 0,
        'enable_categorical': True,
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),
        'random_state': random_seed,
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),
        'max_delta_step': trial.suggest_int('max_delta_step', 1, 10)
    }

    # Initialize StratifiedKFold cross-validation
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_seed)

    auc_scores = []  # Store AUC scores for each fold

    # StratifiedKFold cross-validation loop
    for train_idx, val_idx in cv.split(X_train, y_train):
        X_train_cv, X_val_cv = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_train_cv, y_val_cv = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        # Initialize and train the model
        model = xgb.XGBClassifier(**param)
        model.fit(X_train_cv, y_train_cv, 
                  eval_set=[(X_val_cv, y_val_cv)],
                  verbose=False)

        # Predict and calculate AUC for the fold
        y_pred = model.predict_proba(X_val_cv)[:, 1]  # Get the probability for the positive class
        auc = roc_auc_score(y_val_cv, y_pred)
        auc_scores.append(auc)

    # Return the average AUC from the StratifiedKFold validation
    mean_auc = np.mean(auc_scores)
    return mean_auc

# Create an Optuna study for hyperparameter optimization
study = optuna.create_study(direction='maximize')  # Maximizing AUC score
study.optimize(objective, n_trials=25, show_progress_bar=True)

# After the optimization, you can retrieve the best trial and parameters
best_trial = study.best_trial
print(f"Best trial parameters: {best_trial.params}")
# Out:
# [I 2025-11-11 20:17:48,934] A new study created in memory with name: no-name-9c9adf0e-2939-46ca-a846-29cede71b2c7
#   0%|          | 0/25 [00:00<?, ?it/s]
# [I 2025-11-11 20:17:53,054] Trial 0 finished with value: 0.8022458140409794 and parameters: {'learning_rate': 0.10763407539125046, 'n_estimators': 471, 'max_depth': 3, 'subsample': 0.5343105035459877, 'colsample_bytree': 0.87465381172171, 'reg_alpha': 8.507803734419277, 'reg_lambda': 6.986173441671124, 'min_child_weight': 6, 'gamma': 1.2216256707968927, 'max_delta_step': 8}. Best is trial 0 with value: 0.8022458140409794.
# [I 2025-11-11 20:18:01,039] Trial 1 finished with value: 0.8024392071418414 and parameters: {'learning_rate': 0.11851861055446825, 'n_estimators': 1185, 'max_depth': 12, 'subsample': 0.6414378462710548, 'colsample_bytree': 0.8093361107513153, 'reg_alpha': 2.7818022421601194, 'reg_lambda': 6.812646139636418, 'min_child_weight': 5, 'gamma': 4.531419310724958, 'max_delta_step': 5}. Best is trial 1 with value: 0.8024392071418414.
# [I 2025-11-11 20:18:07,749] Trial 2 finished with value: 0.802091059150343 and parameters: {'learning_rate': 0.19317180003014095, 'n_estimators': 1045, 'max_depth': 11, 'subsample': 0.9337878469165738, 'colsample_bytree': 0.5050590339779084, 'reg_alpha': 6.382826246779926, 'reg_lambda': 0.40349636163702907, 'min_child_weight': 8, 'gamma': 4.42288544872005, 'max_delta_step': 1}. Best is trial 1 with value: 0.8024392071418414.
# [I 2025-11-11 20:18:09,224] Trial 3 finished with value: 0.8023854060557088 and parameters: {'learning_rate': 0.12328783669562908, 'n_estimators': 159, 'max_depth': 6, 'subsample': 0.5555484306769678, 'colsample_bytree': 0.8098954172992678, 'reg_alpha': 7.425062151292588, 'reg_lambda': 3.169495996460433, 'min_child_weight': 4, 'gamma': 3.979107103819545, 'max_delta_step': 3}. Best is trial 1 with value: 0.8024392071418414.
# [I 2025-11-11 20:18:26,911] Trial 4 finished with value: 0.8028265960179949 and parameters: {'learning_rate': 0.016545869140211916, 'n_estimators': 2301, 'max_depth': 12, 'subsample': 0.6283518086854231, 'colsample_bytree': 0.5325923282245277, 'reg_alpha': 5.025426268778974, 'reg_lambda': 4.949294023930322, 'min_child_weight': 1, 'gamma': 3.4546483180857845, 'max_delta_step': 1}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:18:43,127] Trial 5 finished with value: 0.7971677106584523 and parameters: {'learning_rate': 0.17847651678200807, 'n_estimators': 2319, 'max_depth': 15, 'subsample': 0.9195209589657115, 'colsample_bytree': 0.6589246988296378, 'reg_alpha': 5.914862744138073, 'reg_lambda': 3.8180139069195382, 'min_child_weight': 7, 'gamma': 0.7763832416079142, 'max_delta_step': 9}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:19:04,095] Trial 6 finished with value: 0.8022249625412463 and parameters: {'learning_rate': 0.19616851883989914, 'n_estimators': 2410, 'max_depth': 5, 'subsample': 0.8522491135642802, 'colsample_bytree': 0.9462626792255616, 'reg_alpha': 6.918617678352614, 'reg_lambda': 9.80132261424399, 'min_child_weight': 4, 'gamma': 3.4754254067857953, 'max_delta_step': 5}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:19:32,116] Trial 7 finished with value: 0.7949786834374886 and parameters: {'learning_rate': 0.11881327416039235, 'n_estimators': 2890, 'max_depth': 4, 'subsample': 0.6223306332806539, 'colsample_bytree': 0.8388904642846038, 'reg_alpha': 5.618975873348439, 'reg_lambda': 8.410079027905496, 'min_child_weight': 6, 'gamma': 1.1061699321880987, 'max_delta_step': 10}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:19:44,959] Trial 8 finished with value: 0.7930535978390278 and parameters: {'learning_rate': 0.2374222515654389, 'n_estimators': 1402, 'max_depth': 14, 'subsample': 0.9845356201595369, 'colsample_bytree': 0.5069483442787945, 'reg_alpha': 2.2222756330274596, 'reg_lambda': 8.997193326836085, 'min_child_weight': 4, 'gamma': 0.22788768590200792, 'max_delta_step': 7}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:19:53,349] Trial 9 finished with value: 0.8027128236083529 and parameters: {'learning_rate': 0.045324571625090834, 'n_estimators': 1159, 'max_depth': 15, 'subsample': 0.6990130387469573, 'colsample_bytree': 0.7897991656066332, 'reg_alpha': 7.167143396231835, 'reg_lambda': 6.071928141248682, 'min_child_weight': 10, 'gamma': 3.213415452025453, 'max_delta_step': 3}. Best is trial 4 with value: 0.8028265960179949.
# [I 2025-11-11 20:20:15,113] Trial 10 finished with value: 0.8029832416577205 and parameters: {'learning_rate': 0.011780066761881855, 'n_estimators': 1987, 'max_depth': 8, 'subsample': 0.7827199193621063, 'colsample_bytree': 0.6115659219730676, 'reg_alpha': 0.3776494321648096, 'reg_lambda': 1.4373102160245392, 'min_child_weight': 1, 'gamma': 2.331349835488827, 'max_delta_step': 1}. Best is trial 10 with value: 0.8029832416577205.
# [I 2025-11-11 20:20:39,514] Trial 11 finished with value: 0.8027538663414143 and parameters: {'learning_rate': 0.010474617534938307, 'n_estimators': 2019, 'max_depth': 8, 'subsample': 0.7728457091786604, 'colsample_bytree': 0.6350834585918437, 'reg_alpha': 0.110825993971293, 'reg_lambda': 0.15836870231428435, 'min_child_weight': 1, 'gamma': 2.062378919240875, 'max_delta_step': 1}. Best is trial 10 with value: 0.8029832416577205.
# [I 2025-11-11 20:21:01,847] Trial 12 finished with value: 0.8030711244423987 and parameters: {'learning_rate': 0.010833125215213592, 'n_estimators': 1890, 'max_depth': 9, 'subsample': 0.7893196817884234, 'colsample_bytree': 0.6200331186134922, 'reg_alpha': 2.9304409140830057, 'reg_lambda': 2.3983150700071225, 'min_child_weight': 1, 'gamma': 2.129228211428183, 'max_delta_step': 3}. Best is trial 12 with value: 0.8030711244423987.
# [I 2025-11-11 20:21:16,247] Trial 13 finished with value: 0.8024543506608877 and parameters: {'learning_rate': 0.023982811288600907, 'n_estimators': 1808, 'max_depth': 8, 'subsample': 0.7727600610072057, 'colsample_bytree': 0.6633860871448218, 'reg_alpha': 0.3806825559937122, 'reg_lambda': 1.9757219978177756, 'min_child_weight': 2, 'gamma': 2.26247191793722, 'max_delta_step': 3}. Best is trial 12 with value: 0.8030711244423987.
# [I 2025-11-11 20:21:34,884] Trial 14 finished with value: 0.8027858657370383 and parameters: {'learning_rate': 0.01120231464104779, 'n_estimators': 1775, 'max_depth': 10, 'subsample': 0.8492877358791951, 'colsample_bytree': 0.610188961212324, 'reg_alpha': 3.149258373526738, 'reg_lambda': 2.183361607283957, 'min_child_weight': 2, 'gamma': 1.8089330728003392, 'max_delta_step': 3}. Best is trial 12 with value: 0.8030711244423987.
# [I 2025-11-11 20:21:54,033] Trial 15 finished with value: 0.8030639592568962 and parameters: {'learning_rate': 0.03217723240461182, 'n_estimators': 2954, 'max_depth': 7, 'subsample': 0.8452622298816644, 'colsample_bytree': 0.7268738663959968, 'reg_alpha': 1.399494123723003, 'reg_lambda': 1.5110774824629791, 'min_child_weight': 3, 'gamma': 2.8004709721932577, 'max_delta_step': 2}. Best is trial 12 with value: 0.8030711244423987.
# [I 2025-11-11 20:22:15,444] Trial 16 finished with value: 0.8031818356856046 and parameters: {'learning_rate': 0.03372492380022957, 'n_estimators': 2895, 'max_depth': 6, 'subsample': 0.8425984862104268, 'colsample_bytree': 0.7103902126215188, 'reg_alpha': 1.7251366103536565, 'reg_lambda': 3.436893437455015, 'min_child_weight': 3, 'gamma': 2.6834217637975333, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:22:39,754] Trial 17 finished with value: 0.8002579191174932 and parameters: {'learning_rate': 0.06805007871519986, 'n_estimators': 2545, 'max_depth': 6, 'subsample': 0.7105930124775961, 'colsample_bytree': 0.7200072656090102, 'reg_alpha': 3.989313500848282, 'reg_lambda': 3.8644750777270307, 'min_child_weight': 3, 'gamma': 1.6479473766703205, 'max_delta_step': 6}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:22:47,487] Trial 18 finished with value: 0.8028717363723199 and parameters: {'learning_rate': 0.02237673756641969, 'n_estimators': 723, 'max_depth': 10, 'subsample': 0.8964141170298826, 'colsample_bytree': 0.5635878594556681, 'reg_alpha': 4.05224119281056, 'reg_lambda': 5.150569498721366, 'min_child_weight': 2, 'gamma': 2.814144173986678, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:23:07,412] Trial 19 finished with value: 0.8026782795182342 and parameters: {'learning_rate': 0.0528884885200495, 'n_estimators': 2711, 'max_depth': 9, 'subsample': 0.8174478759247187, 'colsample_bytree': 0.698233896138186, 'reg_alpha': 1.5074342616088465, 'reg_lambda': 3.4453033147538887, 'min_child_weight': 3, 'gamma': 4.972958589519064, 'max_delta_step': 6}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:23:28,619] Trial 20 finished with value: 0.8013745182567916 and parameters: {'learning_rate': 0.030780053760672152, 'n_estimators': 1524, 'max_depth': 5, 'subsample': 0.7144058545052258, 'colsample_bytree': 0.7650173447173125, 'reg_alpha': 9.690325005768475, 'reg_lambda': 4.816638224330196, 'min_child_weight': 5, 'gamma': 0.0094202261165246, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:23:52,732] Trial 21 finished with value: 0.8028294786984566 and parameters: {'learning_rate': 0.03465423952955957, 'n_estimators': 2998, 'max_depth': 7, 'subsample': 0.8538384787904076, 'colsample_bytree': 0.7251441039034094, 'reg_alpha': 1.5157483580160458, 'reg_lambda': 1.3806368519860146, 'min_child_weight': 3, 'gamma': 2.8091945601516723, 'max_delta_step': 2}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:24:18,833] Trial 22 finished with value: 0.8031780952455119 and parameters: {'learning_rate': 0.016995272091997214, 'n_estimators': 2738, 'max_depth': 7, 'subsample': 0.8186913554320602, 'colsample_bytree': 0.696141841809342, 'reg_alpha': 1.598084942061175, 'reg_lambda': 2.487793590949525, 'min_child_weight': 2, 'gamma': 3.0027668470335027, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:24:38,864] Trial 23 finished with value: 0.8031480345938258 and parameters: {'learning_rate': 0.016520047969910332, 'n_estimators': 2623, 'max_depth': 6, 'subsample': 0.8034252137376587, 'colsample_bytree': 0.5727653589215422, 'reg_alpha': 4.050005922294954, 'reg_lambda': 2.615911357545231, 'min_child_weight': 2, 'gamma': 3.1116438117516223, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# [I 2025-11-11 20:24:58,123] Trial 24 finished with value: 0.8022160562132019 and parameters: {'learning_rate': 0.016813260357306795, 'n_estimators': 2625, 'max_depth': 3, 'subsample': 0.8952531194870967, 'colsample_bytree': 0.5863407676186685, 'reg_alpha': 3.8743440491469423, 'reg_lambda': 3.1600808564998646, 'min_child_weight': 2, 'gamma': 3.752599392073571, 'max_delta_step': 4}. Best is trial 16 with value: 0.8031818356856046.
# Best trial parameters: {'learning_rate': 0.03372492380022957, 'n_estimators': 2895, 'max_depth': 6, 'subsample': 0.8425984862104268, 'colsample_bytree': 0.7103902126215188, 'reg_alpha': 1.7251366103536565, 'reg_lambda': 3.436893437455015, 'min_child_weight': 3, 'gamma': 2.6834217637975333, 'max_delta_step': 4}

# %%
model = xgb.XGBClassifier(**best_trial.params).fit(X_train, y_train)

# Make predictions and evaluate
y_test_pred = model.predict(X_test)

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75      6988
#            1       0.76      0.70      0.73      7012
#
#     accuracy                           0.74     14000
#    macro avg       0.74      0.74      0.74     14000
# weighted avg       0.74      0.74      0.74     14000

# %%
# Save the trained pipeline model
pickle.dump(model, open('cardiovascular_predictor.pkl', 'wb'))

# %%
# Load the trained model
loaded_model = pickle.load(open('cardiovascular_predictor.pkl', 'rb'))

# Use the loaded model to make predictions
y_pred = loaded_model.predict(X_test)

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.78      0.75      6988
#            1       0.76      0.70      0.73      7012
#
#     accuracy                           0.74     14000
#    macro avg       0.74      0.74      0.74     14000
# weighted avg       0.74      0.74      0.74     14000
